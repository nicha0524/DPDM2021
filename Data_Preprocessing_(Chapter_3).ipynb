# %% [markdown]
# <a href="https://colab.research.google.com/github/nicha0524/DPDM2021/blob/main/Data_Preprocessing_(Chapter_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DPDM2021_DATA' #    เรียกข้อมูลจาก drive
data_cases = pd.read_csv(os.path.join(path,'confirmed-cases.csv')) # read ข้อมูลจาก Excel โดยใช้ คำสั่ง  pd.read_csv
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# # ชี้ข้อมูลในตาราง

# %%
data_cases['risk']  # เรียกข้อมูล เรียกตามชื่อ column
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 512617                    ทัณฑสถาน/เรือนจำ
# 512618                    ทัณฑสถาน/เรือนจำ
# 512619                    ทัณฑสถาน/เรือนจำ
# 512620                    ทัณฑสถาน/เรือนจำ
# 512621                    ทัณฑสถาน/เรือนจำ
# Name: risk, Length: 512622, dtype: object

# %%
data_cases[['risk','age']] #เรียกข้อมูลตามชื่อ column สามารถเรียกได้หลายค่า แต่ต้องใส่ [] ด้วย
# Out:
#                                     risk   age
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ  61.0
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ  74.0
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ  73.0
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ  68.0
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ  66.0
# ...                                  ...   ...
# 512617                  ทัณฑสถาน/เรือนจำ   NaN
# 512618                  ทัณฑสถาน/เรือนจำ   NaN
# 512619                  ทัณฑสถาน/เรือนจำ   NaN
# 512620                  ทัณฑสถาน/เรือนจำ   NaN
# 512621                  ทัณฑสถาน/เรือนจำ   NaN
#
# [512622 rows x 2 columns]

# %%
data_cases['risk'][666] # เรียกข้อมูลใน column 'risk' ข้อมูลที่ 666
# Out:
# 'สนามมวย'

# %% [markdown]
# # ชี้โดยใช้ .iloc[] (แปลงมุมมองให้เป็น matrix)

# %%
data_cases.iloc[4,4] # ชี้ข้อมูลโดยใช่ iloc ชี้ข้อมูลใน แถวที่ 4 หลักที่ 4
# Out:
# 66.0

# %%
data_cases.iloc[-50:,:] # ชี้ข้อมูลโดยใช่ iloc ชี้ข้อมูล 50 แถวสุดท้ายของทุก คอลัมน์
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 512572  512573     26/7/2021  ...               NaN               NaN
# 512573  512574     26/7/2021  ...               NaN               NaN
# 512574  512575     26/7/2021  ...               NaN               NaN
# 512575  512576     26/7/2021  ...               NaN               NaN
# 512576  512577     26/7/2021  ...               NaN               NaN
# 512577  512578     26/7/2021  ...               NaN               NaN
# 512578  512579     26/7/2021  ...               NaN               NaN
# 512579  512580     26/7/2021  ...               NaN               NaN
# 512580  512581     26/7/2021  ...               NaN               NaN
# 512581  512582     26/7/2021  ...               NaN               NaN
# 512582  512583     26/7/2021  ...               NaN               NaN
# 512583  512584     26/7/2021  ...               NaN               NaN
# 512584  512585     26/7/2021  ...               NaN               NaN
# 512585  512586     26/7/2021  ...               NaN               NaN
# 512586  512587     26/7/2021  ...               NaN               NaN
# 512587  512588     26/7/2021  ...               NaN               NaN
# 512588  512589     26/7/2021  ...               NaN               NaN
# 512589  512590     26/7/2021  ...               NaN               NaN
# 512590  512591     26/7/2021  ...               NaN               NaN
# 512591  512592     26/7/2021  ...               NaN               NaN
# 512592  512593     26/7/2021  ...               NaN               NaN
# 512593  512594     26/7/2021  ...               NaN               NaN
# 512594  512595     26/7/2021  ...               NaN               NaN
# 512595  512596     26/7/2021  ...               NaN               NaN
# 512596  512597     26/7/2021  ...               NaN               NaN
# 512597  512598     26/7/2021  ...               NaN               NaN
# 512598  512599     26/7/2021  ...               NaN               NaN
# 512599  512600     26/7/2021  ...               NaN               NaN
# 512600  512601     26/7/2021  ...               NaN               NaN
# 512601  512602     26/7/2021  ...               NaN               NaN
# 512602  512603     26/7/2021  ...               NaN               NaN
# 512603  512604     26/7/2021  ...               NaN               NaN
# 512604  512605     26/7/2021  ...               NaN               NaN
# 512605  512606     26/7/2021  ...               NaN               NaN
# 512606  512607     26/7/2021  ...               NaN               NaN
# 512607  512608     26/7/2021  ...               NaN               NaN
# 512608  512609     26/7/2021  ...               NaN               NaN
# 512609  512610     26/7/2021  ...               NaN               NaN
# 512610  512611     26/7/2021  ...               NaN               NaN
# 512611  512612     26/7/2021  ...               NaN               NaN
# 512612  512613     26/7/2021  ...               NaN               NaN
# 512613  512614     26/7/2021  ...               NaN               NaN
# 512614  512615     26/7/2021  ...               NaN               NaN
# 512615  512616     26/7/2021  ...               NaN               NaN
# 512616  512617     26/7/2021  ...               NaN               NaN
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [50 rows x 11 columns]

# %%
data_cases.iloc[-50:,[3,6,8]] # ชี้ข้อมูลโดยใช่ iloc ชี้ข้อมูล 50 แถวสุดท้ายของ คอลัมน์ที่ 3 ,6 ,9
# Out:
#          sex nationality              risk
# 512572  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512573  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512574  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512575  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512576  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512577  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512578  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512579  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512580  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512581  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512582  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512583  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512584  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512585  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512586  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512587  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512588  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512589  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512590  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512591  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512592  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512593  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512594  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512595  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512596  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512597  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512598   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512599  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512600  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512601  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512602  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512603  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512604  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512605  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512606  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512607  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512608  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512609  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512610  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512611  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512612  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512613   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512614   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512615   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512616   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512617   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512618   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512619   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512620   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512621   ชาย         NaN  ทัณฑสถาน/เรือนจำ

# %% [markdown]
# # Descriptive Statistics of Data

# %%
data_cases.describe() # .describe() ดูข้อมูลทางสถิติ จะคำนวนใน column ที่เป็นตัวเลข
# Out:
#                  No.            age
# count  512622.000000  462839.000000
# mean   256311.500000      35.529470
# std    147981.369183      16.153885
# min         1.000000       1.000000
# 25%    128156.250000      25.000000
# 50%    256311.500000      34.000000
# 75%    384466.750000      46.000000
# max    512622.000000     108.000000

# %% [markdown]
# # Missing Value
#
#
#
# *   Null
# *   NaN = Not a Number
# *   NA = Not available

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull() #.isnull() ดูว่าม่ค่าว่างมั้ย ถ้ามีจะขึ้น True
# Out:
#           No.  announce_date  ...  province_of_onset  district_of_onset
# 0       False          False  ...              False               True
# 1       False          False  ...              False               True
# 2       False          False  ...              False              False
# 3       False          False  ...              False               True
# 4       False          False  ...              False               True
# ...       ...            ...  ...                ...                ...
# 512617  False          False  ...               True               True
# 512618  False          False  ...               True               True
# 512619  False          False  ...               True               True
# 512620  False          False  ...               True               True
# 512621  False          False  ...               True               True
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull().any()  # .any() คือ Or ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases.isnull().any().any()
# Out:
# True

# %%
data_cases.isnull().all()  # .all() คือ and ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# # Handling Missing Value 1 (ลบค่า missing )

# %%
data_cases.shape #ดูขนาดของข้อมูล
# Out:
# (512622, 11)

# %%
data_cases_M1 = data_cases.dropna() #.dropna() ตัดค่าผิดปกติ (ค่าผิดปกติในที่นี้คือค่าว่าง)

# %%
data_cases_M1.shape
# Out:
# (362205, 11)

# %% [markdown]
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data

# %%
print('size before drop = ',len(data_cases))   #จำนวนข้อมูลก่อนตัด missing
print('size after drop = ', len(data_cases_M1)) #จำนวนข้อมูลหลังตัด missing
print('we lost ', ((len(data_cases)-len(data_cases_M1))/len(data_cases))*100, '% of data') #จำนวนข้อมูลหลังตัด missing
# Out:
# size before drop =  512622
# size after drop =  362205
# we lost  29.342673548930794 % of data

# %%
# ใช้ f'string
print(f'size before drop = {len(data_cases)}') #จำนวนข้อมูลก่อนตัด missing 
print('size after drop = ', len(data_cases_M1)) #จำนวนข้อมูลหลังตัด missing
print(f'we lost {((len(data_cases)-len(data_cases_M1))/len(data_cases))*100:.2f}% of data')#จำนวนข้อมูลหลังตัด missing (: .2 กำหนดจุดทศนิยม)
# Out:
# size before drop = 512622
# size after drop =  362205
# we lost 29.34% of data

# %% [markdown]
# ## Handling Missing Value 1.5 (ลบค่า missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_M15 = data_cases.dropna(subset=['Notified date', 'sex', 'age']) #.dropna(subset=[]) ลบค่า missing เฉพาะใน column Notified date, sex, age

# %%
data_cases_M15.shape #ดูขนาดของข้อมูลหลังจากที่ตัด missing แล้ว
# Out:
# (449552, 11)

# %%
data_cases_M15
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 47          48      6/3/2020  ...     กรุงเทพมหานคร           คลองตัน
# 124        125      6/3/2021  ...          ปทุมธานี           ธัญบุรี
# 161        162     17/3/2020  ...      สุราษฎร์ธานี             เมือง
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 186        187     18/3/2020  ...          ร้อยเอ็ด         เชียงขวัญ
# ...        ...           ...  ...               ...               ...
# 511576  511577     26/7/2021  ...     กรุงเทพมหานคร       บางขุนเทียน
# 511577  511578     26/7/2021  ...     กรุงเทพมหานคร            บางบอน
# 511578  511579     26/7/2021  ...     กรุงเทพมหานคร           ทุ่งครุ
# 511579  511580     26/7/2021  ...     กรุงเทพมหานคร             พญาไท
# 511580  511581     26/7/2021  ...     กรุงเทพมหานคร           มีนบุรี
#
# [449552 rows x 11 columns]

# %% [markdown]
# HW
#
# ```print``` ของ missing 1.5
#
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data
#
# now we have x% more data than handling_missing1

# %%
A=(len(data_cases)/len(data_cases)) 
B1=(len(data_cases)-len(data_cases_M15))/len(data_cases) #data ตัด missing เฉพาะ Column ออกแล้ว
B2=(len(data_cases)-len(data_cases_M1))/len(data_cases)  # data ตัด missing ทั้งหมด ออกแล้ว

print(A)
print(B1)
print(B2)
# Out:
# 1.0
# 0.12303412651037217
# 0.2934267354893079

# %%
print(f'size before drop = {len(data_cases)}') #จำนวนข้อมูลก่อนตัด missing 
print('size after drop = ', len(data_cases_M15)) #จำนวนข้อมูลหลังตัด missing
print(f'we lost {((len(data_cases)-len(data_cases_M15))/len(data_cases))*100:.2f}% of data')#จำนวนข้อมูลหลังตัด missing (: .2 กำหนดจุดทศนิยม)
print(f'now we have {((A-B1)-(A-B2))*100:.2f}% more data than hondling_missing1' )
# Out:
# size before drop = 512622
# size after drop =  449552
# we lost 12.30% of data
# now we have 17.04% more data than hondling_missing1

# %% [markdown]
# ### Handling Missing Value 2 แทนด้วยค่าที่เหมาะสม หรือสร้าง class ใหม่

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
from matplotlib import  pyplot as plt

# %%
data_cases['age'].mean(skipna=False) # ถ้าฟังชั่น ไม่ได้ป้องกัน data ที่มี missing ไว้
# Out:
# nan

# %%
data_cases[['Notified date']]=data_cases[['Notified date']].fillna('99/99/9999') # fillna() เติมค่า '99/99/9999' (เติมใน column ที่เป็นค่า misssing) ลงใน data_cases[['Notified date']]

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull().any() #.isnull() ดูว่าม่ค่าว่างมั้ย ถ้ามีจะขึ้น True  # .any() คือ Or ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### ดู column unit

# %%
data_cases['Unit'] #เรียกดูข้อมูลใน column  name: Unit
# Out:
# 0          ปี
# 1          ปี
# 2          ปี
# 3          ปี
# 4          ปี
#          ...
# 512617    NaN
# 512618    NaN
# 512619    NaN
# 512620    NaN
# 512621    NaN
# Name: Unit, Length: 512622, dtype: object

# %%
set(data_cases['Unit']) # หา unigue value (unigue: เอกลักษณ์) ' วัน' และ  'วัน' ไม่เหมือนกันเพราะเว้นวรรคไม่เท่ากัน
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %% [markdown]
# ### [PD] วิธีเลือก record โดยการกำหนดค่า

# %%
data_cases[data_cases['Unit']=='วัน'] #เลือกข้อมูลใน data_cases  ,Column: Unit เรียกค่า 'วัน'
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 19706    19707      2/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 23791    23792     10/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 40962    40963     18/4/2021  ...        นครราชสีมา           เสิงสาง
# 57747    57748     27/4/2021  ...               NaN               NaN
# 72457    72458      4/5/2021  ...     กรุงเทพมหานคร            สายไหม
# ...        ...           ...  ...               ...               ...
# 443474  443475     22/7/2021  ...            นครปฐม           สามพราน
# 474582  474583     24/7/2021  ...        ฉะเชิงเทรา           บางปะกง
# 477365  477366     24/7/2021  ...      สุราษฎร์ธานี            พุนพิน
# 488901  488902     25/7/2021  ...            ชลบุรี          บางละมุง
# 504780  504781     26/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
#
# [64 rows x 11 columns]

# %%
data_cases[data_cases['Unit']==' วัน']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 138721  138722     27/5/2021  ...       สมุทรปราการ            บางพลี
#
# [1 rows x 11 columns]

# %% [markdown]
# ###data_frame[list_of_logics] #list_of_logics มีขนาดเท่ากับจำนวน record ของ data_frame

# %%
data_cases['Unit']=='วัน' #list_of_logics
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 512617    False
# 512618    False
# 512619    False
# 512620    False
# 512621    False
# Name: Unit, Length: 512622, dtype: bool

# %%
data_cases[data_cases['Unit']=='วัน'].sort_values (by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 339653  339654     12/7/2021  ...       สมุทรปราการ            บางพลี
# 375821  375822     16/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
# 367305  367306     15/7/2021  ...       สมุทรปราการ  เมืองสมุทรปราการ
# 377872  377873     16/7/2021  ...     กรุงเทพมหานคร               NaN
# 409055  409056     19/7/2021  ...       สมุทรปราการ         พระประแดง
# ...        ...           ...  ...               ...               ...
# 19706    19707      2/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 321015  321016     10/7/2021  ...       สมุทรปราการ  เมืองสมุทรปราการ
# 291137  291138      6/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
# 443474  443475     22/7/2021  ...            นครปฐม           สามพราน
# 285988  285989      5/7/2021  ...            ชลบุรี           ศรีราชา
#
# [64 rows x 11 columns]

# %% [markdown]
# ###Quiz 10 หา records ต่อไปนี้
#
# records ที่ กักตัวที่ขอนแก่น
#
# records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร
#
# records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม
#
# records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่

# %% [markdown]
# ####records ที่ กักตัวที่ขอนแก่น

# %%
set(data_cases['province_of_isolation'])
# Out:
# {nan,
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน'}

# %%
data_cases[data_cases['province_of_isolation']== 'ขอนแก่น']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 505598  505599     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 505599  505600     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [3707 rows x 11 columns]

# %% [markdown]
# ####records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร

# %%
data_cases[(data_cases['province_of_isolation']== 'ขอนแก่น')|(data_cases['province_of_isolation']== 'นครราชสีมา')|(data_cases['province_of_isolation']== 'อุดรธานี')] # | 'หรือ' ต้องใส่ () ด้วย data_cases[  (data_cases['...'])  |  (data_cases['...'])  ]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 189        190     18/3/2020  ...        นครราชสีมา             พิมาย
# 207        208     18/3/2020  ...     กรุงเทพมหานคร               NaN
# 212        213     18/3/2020  ...        นครราชสีมา       วังน้ำเขียว
# 284        285     20/3/2020  ...        นครราชสีมา   เมืองนครราชสีมา
# ...        ...           ...  ...               ...               ...
# 507218  507219     26/7/2021  ...               NaN               NaN
# 507219  507220     26/7/2021  ...               NaN               NaN
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [10539 rows x 11 columns]

# %% [markdown]
# ####records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม

# %%
data_cases[(data_cases['sex']== 'หญิง')|(data_cases['province_of_onset']== 'กรุงเทพมหานคร')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512608  512609     26/7/2021  ...               NaN               NaN
# 512609  512610     26/7/2021  ...               NaN               NaN
# 512610  512611     26/7/2021  ...               NaN               NaN
# 512611  512612     26/7/2021  ...               NaN               NaN
# 512612  512613     26/7/2021  ...               NaN               NaN
#
# [314420 rows x 11 columns]

# %% [markdown]
# ####records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่

# %%
data_cases[(data_cases['province_of_isolation']=='เชียงใหม่') & 
           (data_cases['sex']=='ชาย') &
           (data_cases['age']>=18) &
           (data_cases['age']<=22)].sort_values(by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 37385    37386     15/4/2021  ...         เชียงใหม่            แม่ออน
# 38887    38888     16/4/2021  ...         เชียงใหม่         ดอยสะเก็ด
# 81287    81288      9/5/2021  ...         เชียงใหม่           สันทราย
# 47078    47079     22/4/2021  ...         เชียงใหม่            แม่ริม
# 78869    78870      8/5/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# ...        ...           ...  ...               ...               ...
# 34470    34471     13/4/2021  ...         เชียงใหม่               NaN
# 34445    34446     13/4/2021  ...         เชียงใหม่               NaN
# 34439    34440     13/4/2021  ...         เชียงใหม่               NaN
# 34506    34507     13/4/2021  ...         เชียงใหม่               NaN
# 497302  497303     26/7/2021  ...         เชียงใหม่             หางดง
#
# [411 rows x 11 columns]

# %%
data_cases[(data_cases['sex']== 'ชาย')&(data_cases['province_of_isolation']== 'เชียงใหม่')&((data_cases['age']>=18) & (data_cases['age']<=22))].sort_values(by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 37385    37386     15/4/2021  ...         เชียงใหม่            แม่ออน
# 38887    38888     16/4/2021  ...         เชียงใหม่         ดอยสะเก็ด
# 81287    81288      9/5/2021  ...         เชียงใหม่           สันทราย
# 47078    47079     22/4/2021  ...         เชียงใหม่            แม่ริม
# 78869    78870      8/5/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# ...        ...           ...  ...               ...               ...
# 34470    34471     13/4/2021  ...         เชียงใหม่               NaN
# 34445    34446     13/4/2021  ...         เชียงใหม่               NaN
# 34439    34440     13/4/2021  ...         เชียงใหม่               NaN
# 34506    34507     13/4/2021  ...         เชียงใหม่               NaN
# 497302  497303     26/7/2021  ...         เชียงใหม่             หางดง
#
# [411 rows x 11 columns]

# %%
a =data_cases[data_cases['sex'] =='ชาย']
a = a[a['province_of_isolation'] == 'เชียงใหม่']
a = a[a['age'] >=18]
a = a[a['age'] <=22]
a.sort_values(by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 37385    37386     15/4/2021  ...         เชียงใหม่            แม่ออน
# 38887    38888     16/4/2021  ...         เชียงใหม่         ดอยสะเก็ด
# 81287    81288      9/5/2021  ...         เชียงใหม่           สันทราย
# 47078    47079     22/4/2021  ...         เชียงใหม่            แม่ริม
# 78869    78870      8/5/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# ...        ...           ...  ...               ...               ...
# 34470    34471     13/4/2021  ...         เชียงใหม่               NaN
# 34445    34446     13/4/2021  ...         เชียงใหม่               NaN
# 34439    34440     13/4/2021  ...         เชียงใหม่               NaN
# 34506    34507     13/4/2021  ...         เชียงใหม่               NaN
# 497302  497303     26/7/2021  ...         เชียงใหม่             หางดง
#
# [411 rows x 11 columns]

# %%
set(data_cases['Unit'])
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
plt.hist(data_cases['Unit'].dropna());

# %%
data_cases[['Unit']]=data_cases[['Unit']].fillna(' ปี ') #เติม "ปี" ลงใน column ที่เป็นค่าว่าง

# %%
data_cases.isnull().any() #ตรวจสอบค่า missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases[['nationality']]=data_cases[['nationality']].fillna(' ไทย? ')

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# Handling Missing Value 3 แทนด้วยค่ากลาง

# %%
data_cases[['age']]=data_cases[['age']].fillna(data_cases[['age']].mean()) # เติม missing ด้วยค่าเฉลี่ย (.mean())

# %%
data_cases.isnull().any() #ตรวจสอบค่า missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
sorted(list(data_cases['sex'].dropna())) # เรียงข้อมูล sorted() ที่ตัด missing แล้ว .dropna()
# Out:
# ['ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  'ชาย',
#  ...]

# %%
len(list(data_cases['sex'].dropna())) # ดูจำนวนข้อมูลที่ตัด missing แล้ว
# Out:
# 481884

# %%
data_cases[['sex']].dropna().mode() # หาค่าฐานนิยม .mode() ในข้อมูลที่ตัด missing แล้ว
# Out:
#    sex
# 0  ชาย

# %%
data_cases[['sex']].dropna().mode().iloc[0,0] #หา .mode()  #.iloc[0,0] ใช้เพื่อให้ข้อมูลที่เติมลงไปไม่เป็นตาราง(ชี้ข้อมุลใ column ที่ถูกเลือก)
# Out:
# 'ชาย'

# %%
data_cases[['sex']]=data_cases[['sex']].fillna(data_cases[['sex']].dropna().mode().iloc[0,0]) #แทน .mode() ลงในข้อมูลที่เป็น missing #.iloc[0,0] ใช้เพื่อให้ข้อมูลที่เติมลงไปไม่เป็นตาราง(ชี้ข้อมุลใ column ที่ถูกเลือก)

# %%
data_cases.isnull().any() #ตรวจสอบค่า missing ถ้าขึ้น False แสดงว่าไม่มี missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['province_of_onset']].dropna().mode().iloc[0,0] #หา .mode()  #.iloc[0,0] ใช้เพื่อให้ข้อมูลที่เติมลงไปไม่เป็นตาราง(ชี้ข้อมุลใ column ที่ถูกเลือก)
# Out:
# 'กรุงเทพมหานคร'

# %%
data_cases[['province_of_onset']]=data_cases[['province_of_onset']].fillna(data_cases[['province_of_onset']].dropna().mode().iloc[0,0]) # แทน  .mode() ในค่าว่าง ของ column 'province_of_onset'

# %%
data_cases.isnull().any() #ตรวจสอบค่า missing ถ้าขึ้น False แสดงว่าไม่มี missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cases['province_of_isolation'].value_counts() #นับข้อมูล
# Out:
# กรุงเทพมหานคร    161884
# สมุทรสาคร         42372
# สมุทรปราการ       36154
# นนทบุรี           29337
# ชลบุรี            22474
#                   ...
# พังงา               503
# ลำพูน               502
# แพร่                467
# บึงกาฬ              312
# แม่ฮ่องสอน          125
# Name: province_of_isolation, Length: 77, dtype: int64

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...     กรุงเทพมหานคร               NaN
# 512618  512619     26/7/2021  ...     กรุงเทพมหานคร               NaN
# 512619  512620     26/7/2021  ...     กรุงเทพมหานคร               NaN
# 512620  512621     26/7/2021  ...     กรุงเทพมหานคร               NaN
# 512621  512622     26/7/2021  ...     กรุงเทพมหานคร               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# ###Group by (การจัดกลุ่มข้อมูลที่มีลักษณะซ้ำกัน)

# %%
data_cases.groupby(['province_of_isolation']).agg([ 'count' ])
# Out:
#                           No. announce_date  ... province_of_onset district_of_onset
#                         count         count  ...             count             count
# province_of_isolation                        ...
# กระบี่                   1005          1005  ...              1005               738
# กรุงเทพมหานคร          161884        161884  ...            161884            109118
# กาญจนบุรี                2756          2756  ...              2756              2190
# กาฬสินธุ์                2047          2047  ...              2047              1903
# กำแพงเพชร                1800          1800  ...              1800              1770
# ...                       ...           ...  ...               ...               ...
# เพชรบุรี                11268         11268  ...             11268             10977
# เพชรบูรณ์                1537          1537  ...              1537              1514
# เลย                       853           853  ...               853               610
# แพร่                      467           467  ...               467               428
# แม่ฮ่องสอน                125           125  ...               125               111
#
# [77 rows x 10 columns]

# %%
data_cases.groupby('province_of_isolation',sort=False).size()
# Out:
# province_of_isolation
# กรุงเทพมหานคร      161884
# นครปฐม              11070
# นนทบุรี             29337
# ประจวบคีรีขันธ์      4318
# ภูเก็ต               1181
#                     ...
# อ่างทอง              2012
# ระนอง                2132
# ตราด                  907
# น่าน                  635
# บึงกาฬ                312
# Length: 77, dtype: int64

# %% [markdown]
# #### agg: min,max,sum,count,mean,median,std,nunique

# %%
data_cases.groupby(['province_of_isolation']).agg(['count'])
# Out:
#                           No. announce_date  ... province_of_onset district_of_onset
#                         count         count  ...             count             count
# province_of_isolation                        ...
# กระบี่                   1005          1005  ...              1005               738
# กรุงเทพมหานคร          161884        161884  ...            161884            109118
# กาญจนบุรี                2756          2756  ...              2756              2190
# กาฬสินธุ์                2047          2047  ...              2047              1903
# กำแพงเพชร                1800          1800  ...              1800              1770
# ...                       ...           ...  ...               ...               ...
# เพชรบุรี                11268         11268  ...             11268             10977
# เพชรบูรณ์                1537          1537  ...              1537              1514
# เลย                       853           853  ...               853               610
# แพร่                      467           467  ...               467               428
# แม่ฮ่องสอน                125           125  ...               125               111
#
# [77 rows x 10 columns]

# %%
data_cases[['province_of_isolation','province_of_onset']].groupby('province_of_isolation',sort=False).agg(['count','max'])
# Out:
#                       province_of_onset
#                                   count           max
# province_of_isolation
# กรุงเทพมหานคร                    161884       ไม่ระบุ
# นครปฐม                            11070     เพชรบูรณ์
# นนทบุรี                           29337          แพร่
# ประจวบคีรีขันธ์                    4318     เพชรบูรณ์
# ภูเก็ต                             1181          แพร่
# ...                                 ...           ...
# อ่างทอง                            2012     เพชรบูรณ์
# ระนอง                              2132  สุราษฎร์ธานี
# ตราด                                907       สุโขทัย
# น่าน                                635       เวียงสา
# บึงกาฬ                              312      อุดรธานี
#
# [77 rows x 2 columns]

# %% [markdown]
# ###แก้ missing ใน province_of_isolation เติมค่า onset ใน isolation ก่อนเติม mode

# %% [markdown]
# ####Loop [PD]

# %%
for i in range(10): # วนลูป i 10 ครั้ง
     this_data = data_cases.iloc[i,:] #ให้ this_data= data_casesตั้งแต่ตัวที่ i ถึงตัวสุดท้าย

# %%
for record in data_cases.iloc[:10,:].iterrows(): #วนลูป record  โดยใช้ iterrows วนซ้ำตามdata frame
    print(record)
# Out:
# (0, No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    61
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object)
# (1, No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    74
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 1, dtype: object)
# (2, No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# Name: 2, dtype: object)
# (3, No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    68
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 3, dtype: object)
# (4, No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    66
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 4, dtype: object)
# (5, No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    33
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 5, dtype: object)
# (6, No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    57
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 6, dtype: object)
# (7, No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# Name: 7, dtype: object)
# (8, No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    63
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 8, dtype: object)
# (9, No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    28
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# Name: 9, dtype: object)

# %%
for i in range(10):
    print(data_cases.iloc[i,:]) #ให้ this_data= data_casesตั้งแต่ตัวที่ i ถึงตัวสุดท้าย
    print('------------------new line---------------') #เส้นคั้นในการวนแต่ละรอบ
# Out:
# No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    61
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object
# ------------------new line---------------
# No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    74
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 1, dtype: object
# ------------------new line---------------
# No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# Name: 2, dtype: object
# ------------------new line---------------
# No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    68
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 3, dtype: object
# ------------------new line---------------
# No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    66
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 4, dtype: object
# ------------------new line---------------
# No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    33
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 5, dtype: object
# ------------------new line---------------
# No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    57
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 6, dtype: object
# ------------------new line---------------
# No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# Name: 7, dtype: object
# ------------------new line---------------
# No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    63
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 8, dtype: object
# ------------------new line---------------
# No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    28
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# Name: 9, dtype: object
# ------------------new line---------------

# %% [markdown]
# ###เราสามารถกำหนดค่าให้กับตารางทีละ column หรือสร้าง column ใหม่ให้กับตาราง ได้โดยใช้ list ที่มีจำนวนเท่ากับจำนวน record

# %%
data_cases['new col']=list( range( data_cases.shape[0] ) ) #สร้าง column ใหม่ชื่อ 'new col' จาก list ความยาวตาม data_cases.shape[0]

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %% [markdown]
# ###แก้ missing ใน province_of_isolation เติมค่าของ onset ใน isolation ก่อนจะเติมค่า mode

# %%
#วน loop ตาม province_of_isolation แทนค่าในprovince_of_isolation ด้วย province_of_onset แต่ถ้า province_of_onset เป็นค่าว่างจะแทนค่าด้วย mode ของ province_of_isolation จังหวัดนั้น ๆ
new_p_iso = list()

for row in data_cases.iterrows():  #.iterrows()ซึ่งวนซ้ำบน DataFrame 
    if pd.isna(row[1]['province_of_isolation']): 
        if pd.isna(row[1]['province_of_onset']) == False:
            new_p_iso.append(row[1]['province_of_onset'])
        else:
            new_p_iso.append(data_cases[['province_of_isolation']].dropna().mode().iloc[0,0])
    else:
        new_p_iso.append(row[1]['province_of_isolation'])

# %%
len(new_p_iso) # ดูความขนาดของ new_p_iso
# Out:
# 512622

# %%
data_cases['province_of_isolation'] = new_p_iso #ให้ข้อมูล data_cases ใน column province_of_isolation เท่ากับ new_p_iso

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
data_cases.isnull().any() #เช็คค่า missing ถ้าเป็น False แสดงว่า ไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
data_cases2 = pd.read_csv(os.path.join(path,'confirmed-cases.csv')) #เรียกข้อมูล 'pd.read_csv' ตั้งชื่อ data_cases2

# %%
data_cases2[pd.isna(data_cases2['province_of_isolation'])] # เติมค่าว่าง 'pd.isna()' ลงใน data_cases2 column procince_of_isolation
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 39        40     26/2/2020  ...     กรุงเทพมหานคร          ดอนเมือง
# 40        41     28/2/2020  ...           นนทบุรี               NaN
# 41        42     29/2/2020  ...     กรุงเทพมหานคร        วังทองหลาง
# 42        43      2/3/2020  ...     กรุงเทพมหานคร              สาทร
# 140      141     16/3/2020  ...     กรุงเทพมหานคร               NaN
# ...      ...           ...  ...               ...               ...
# 40815  40816     18/4/2021  ...               NaN               NaN
# 40816  40817     18/4/2021  ...               NaN               NaN
# 40817  40818     18/4/2021  ...               NaN               NaN
# 40830  40831     18/4/2021  ...               NaN               NaN
# 40831  40832     18/4/2021  ...               NaN               NaN
#
# [508 rows x 11 columns]

# %%
data_cases[pd.isna(data_cases2['province_of_isolation'])]  #เติมข้อมูลลง data_cases
# Out:
#          No. announce_date  ... district_of_onset new col
# 39        40     26/2/2020  ...          ดอนเมือง      39
# 40        41     28/2/2020  ...               NaN      40
# 41        42     29/2/2020  ...        วังทองหลาง      41
# 42        43      2/3/2020  ...              สาทร      42
# 140      141     16/3/2020  ...               NaN     140
# ...      ...           ...  ...               ...     ...
# 40815  40816     18/4/2021  ...               NaN   40815
# 40816  40817     18/4/2021  ...               NaN   40816
# 40817  40818     18/4/2021  ...               NaN   40817
# 40830  40831     18/4/2021  ...               NaN   40830
# 40831  40832     18/4/2021  ...               NaN   40831
#
# [508 rows x 12 columns]

# %% [markdown]
# ###Handling Missing Value 4 แทนด้วยค่าด้วยค่ากลางของกลุ่ม

# %%
data_cases.isnull().any() #เช็คค่า missing ถ้าเป็น False แสดงว่า ไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
rick_list = list(set(data_cases['risk'])) #ดู set(set คือ ชุดข้อมูลที่มีการแสดงผลไม่เป็นไปตามลำดับ ทำให้ไม่สามารถเข้าถึงข้อมูลโดยการ index ไม่สามารถมีข้อมูลซ้ำกันได้ ) ของ data_cases['risk']
print(rick_list)
# Out:
# [nan, 'บุคลากรด้านการแพทย์และสาธารณสุข', 'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)', 'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)', 'Cluster ชลบุรี โรงเบียร์ 90', 'เดินทางมาจากพื้นที่มีการระบาดของโรค', 'Cluster New Jazz กรุงเทพมหานคร', 'อยุ่ระหว่างสอบสวน', 'Sandbox', 'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน', 'รับจ้างขนของที่ตลาดท่ายาง', 'อยู่ระหว่างสอบสวนโรค', 'ไปยังพื้นที่ที่มีการระบาด', 'Cluster ตราด', 'สถานบันเทิง', "Cluster Memory 90's กรุงเทพมหานคร", 'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด', 'Cluster ทันฑสถานบำบัดพิเศษกลาง', '2.สัมผัสผู้ติดเชื้อ', 'ACF สีลม', 'Cluster มหาสารคาม', 'อื่น', 'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน', 'ผู้ป่วย PUI', 'Cluster บ่อนเทพารักษ์', 'Cluster ผับ Thonglor', 'Cluster ปากช่อง', 'Cluster กรุงเทพมหานคร. คลองเตย', 'ACF เคหะหลักสี่', 'ACF สนามกีฬาธูปะเตมีย์', 'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)', 'ค้นหาเชิงรุก', 'สัมผัสในสถานพยาบาล', 'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ', 'Cluster ระยอง', 'Cluster เรือนจำพิเศษธนบุรี', 'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร', 'Cluster โรงงาน QPP ประจวบฯ', 'ไปแหล่งชุมชน/สถานที่คนหนาแน่น', 'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์', 'Cluster บ่อนไก่อ่างทอง', 'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน', 'Cluster ชลบุรี บริษัทไดกิ้น', 'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน', 'ทัณฑสถาน/เรือนจำ', 'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค', 'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar', 'Cluster จนท. สนามบินสุวรรณภูมิ', 'Cluster จันทบุรี', 'Cluster ทัณฑสถานหญิงกลาง', 'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว', 'คนไทยเดินทางมาจากต่างประเทศ', 'ตรวจสุขภาพแรงงานต่างด้าว', 'Cluster เรือนจำพิเศษกรุงเทพ', 'Cluster ตลาดบางแค/คลองขวาง', 'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.', 'Cluster บ่อนพัทยา/ชลบุรี', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ', 'Cluster ตลาดพรพัฒน์', 'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน', 'Cluster จันทบุรี (ชาวกินี)', 'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน', 'SHUI', 'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น', 'Cluster The Lounge Salaya', 'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)', 'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต', 'อื่นๆ', 'Cluster โรงงานทำขนม บางขุนเทียน', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ', 'Cluster บริษัทศรีสวัสดิ์', 'Cluster สมุทรสาคร', 'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า', 'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า', 'Cluster งานมอเตอร์ โชว์', 'สัมผัสผู้ป่วยที่ติดโควิด', 'ACF สนามกีฬาไทย-ญี่ปุ่น', 'Cluster เรือนจำกลางคลองเปรม', 'อยู่ระหว่างการสอบสวน', 'State Quarantine', 'อยู่ระหว่างการสอบสวน\n', 'ปอดอักเสบ (Pneumonia)', 'ระหว่างสอบสวน', 'Cluster โรงงาน standard can', 'Cluster ตลาดบางพลี', 'พิธีกรรมทางศาสนา', 'คนไทยเดินทางกลับจากต่างประเทศ', 'Cluster ตลาดบางแค', 'สนามมวย', 'อยู่ระหว่างสอบสวน', 'Cluster ตลาดสี่มุมเมือง', 'Cluster สถานบันเทิงย่านทองหล่อ', 'Cluster Icon siam', 'Cluster จันทบุรี (ชาวกินี )', 'Cluster ห้างแสงทอง (สายล่าง)', 'ผับหัวหิน', 'Cluster สมุทรปราการ GRP Hightech', 'Cluster ชลบุรี', 'ร้านอาหาร', 'คนไทยมาจากพื้นที่เสี่ยง', 'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ', 'Cluster บางแค', 'Cluster ระยอง วิริยะประกันภัย', 'Cluster เรือนจำพิเศษมีนบุรี', 'คนต่างชาติเดินทางมาจากต่างประเทศ', 'Cluster โรงงาน  Big Star', 'Cluster คลองเตย', 'ตรวจก่อนทำหัตถการ', 'ระหว่างการสอบสวนโรค', 'Cluster โรงงาน Big Star', 'ผู้ป่วย กรุงเทพมหานคร', 'สัมผัสผู้เดินทางจากต่างประเทศ', 'สถานที่ทำงาน', 'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน', 'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน', 'สัมผัสผู้ป่วยยืนยัน', 'Cluster ตราด ', 'เดินทางมาจากพื้นที่จังหวัดเสี่ยง', 'ระบุไม่ได้', 'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน', 'ตลาด', 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้', 'ศูนย์กักกัน ผู้ต้องกัก', 'ปอดอักเสบ Pneumonia', 'Cluster สมุทรปราการ ตลาดเคหะบางพลี', 'Cluster ตลาดนนทบุรี', 'ACF รองเมือง', 'รอประสาน', 'Refer in', 'ผู้ติดเชื้อในประเทศ']

# %% [markdown]
# #### 'ขอนแก่น'

# %%
datakk=data_cases[data_cases['province_of_onset']=='ขอนแก่น'] # ให้ datakk คือค่า จังหวัดขอนแก่น ใน column 'province_of_onset'

# %%
datakk[['risk']] = datakk[['risk']].fillna(datakk[['risk']].dropna().mode().iloc[0,0])  #เติม(.fillna()) ของ mode ในdatakk['province_of_onset'](ขอนแก่น) ลงไปใน column 'risk'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
datakk
# Out:
#            No. announce_date  ... district_of_onset new col
# 181        182     18/3/2020  ...             เมือง     181
# 463        464     22/3/2020  ...             เมือง     463
# 1467      1468     30/3/2020  ...             เมือง    1467
# 1971      1972      3/4/2020  ...             เมือง    1971
# 2638      2639     15/4/2020  ...            น้ำพอง    2638
# ...        ...           ...  ...               ...     ...
# 507541  507542     26/7/2021  ...               NaN  507541
# 507542  507543     26/7/2021  ...               NaN  507542
# 507543  507544     26/7/2021  ...               NaN  507543
# 507544  507545     26/7/2021  ...               NaN  507544
# 507546  507547     26/7/2021  ...               NaN  507546
#
# [3149 rows x 12 columns]

# %%
datakk[['risk']].dropna().mode().iloc[0,0] #ดู mode ของ datakk[['risk']]
# Out:
# 'ทัณฑสถาน/เรือนจำ'

# %%
datakk.isnull().any() #เช็คค่า missing ถ้าเป็น False แสดงว่า ไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %% [markdown]
# #### 'นครราชสีมา'

# %%
datako = data_cases[data_cases['province_of_onset']=='นครราชสีมา']  # ให้ datako คือค่า จังหวัดนคราชสีมา ใน column 'province_of_onset'

# %%
datako[['risk']] = datako[['risk']].fillna(datako[['risk']].dropna().mode().iloc[0,0]) #เติม(.fillna()) ของ mode ในdatakน['province_of_onset'](นคคราชสีมา) ลงไปใน column 'risk'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
datako
# Out:
#            No. announce_date  ... district_of_onset new col
# 189        190     18/3/2020  ...             พิมาย     189
# 212        213     18/3/2020  ...       วังน้ำเขียว     212
# 284        285     20/3/2020  ...   เมืองนครราชสีมา     284
# 352        353     21/3/2020  ...   เมืองนครราชสีมา     352
# 701        702     23/3/2020  ...   เมืองนครราชสีมา     701
# ...        ...           ...  ...               ...     ...
# 494437  494438     25/7/2021  ...        นครราชสีมา  494437
# 497245  497246     25/7/2021  ...               NaN  497245
# 503473  503474     26/7/2021  ...   เมืองนครราชสีมา  503473
# 505371  505372     26/7/2021  ...            ชุมพวง  505371
# 507716  507717     26/7/2021  ...               NaN  507716
#
# [1450 rows x 12 columns]

# %%
datako[['risk']].dropna().mode().iloc[0,0] #ดู mode ของ datako[['risk']]
# Out:
# 'อยู่ระหว่างการสอบสวน'

# %%
datako.isnull().any() #เช็คค่า missing ถ้าเป็น False แสดงว่า ไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %% [markdown]
# [PD] ต่อตารางแกน Y

# %%
dataKKko = pd.concat([datakk,datako]) #ต่อตารางของข้อมูล datakkกับdatako ใน province_of_onset
dataKKko
# Out:
#            No. announce_date  ... district_of_onset new col
# 181        182     18/3/2020  ...             เมือง     181
# 463        464     22/3/2020  ...             เมือง     463
# 1467      1468     30/3/2020  ...             เมือง    1467
# 1971      1972      3/4/2020  ...             เมือง    1971
# 2638      2639     15/4/2020  ...            น้ำพอง    2638
# ...        ...           ...  ...               ...     ...
# 494437  494438     25/7/2021  ...        นครราชสีมา  494437
# 497245  497246     25/7/2021  ...               NaN  497245
# 503473  503474     26/7/2021  ...   เมืองนครราชสีมา  503473
# 505371  505372     26/7/2021  ...            ชุมพวง  505371
# 507716  507717     26/7/2021  ...               NaN  507716
#
# [4599 rows x 12 columns]

# %%
X = list(set(data_cases['province_of_onset'])) #ให้ x คือ set(set คือ ชุดข้อมูลที่มีการแสดงผลไม่เป็นไปตามลำดับ ทำให้ไม่สามารถเข้าถึงข้อมูลโดยการ index ไม่สามารถมีข้อมูลซ้ำกันได้ ) ของ data_cases['province_of_onset']
X
# Out:
# ['สุมทรสาคร',
#  'กาฬสินธิ์',
#  'ปราจีนบุรี',
#  'สุมุทรปราการ',
#  'สองแคว',
#  'ปัตตานี\u200b',
#  'เวียงสา',
#  'กำแพงเพชร',
#  'ร้อยเอ็็ด',
#  'พระนครศรีอยุทธยา',
#  'สุุราษฎร์ธานี',
#  'เพรบุรี',
#  'ชัยภูมิ',
#  'ราชบุรี',
#  'นคปฐม',
#  'ศีรสะเกษ',
#  'มหาสารคราม',
#  'พิจิตร',
#  'สงขขลา',
#  'สระบุุรี',
#  'นครศรีีธรรมราช',
#  'ชุุมพร',
#  'อำนาจเจริญ',
#  'ปัว',
#  'ศรีสะเกษ',
#  'อุบลราขธานี',
#  'ลำพูน',
#  'เมืองน่าน',
#  'อุดรธานีี',
#  'เชียงใหม่',
#  'สระบุรี',
#  'สอง',
#  'สุพรรณบุรี',
#  'บุรีรัมย์',
#  'นครสวรรค์',
#  'พิษณุโลก',
#  'พะเยา',
#  'สมุทราสาคร',
#  'สมุทรสาคร',
#  'สตูล',
#  'ศีรษะเกษ',
#  'แพร่',
#  'มุกดาหาร',
#  'ปัตตานี',
#  'หนองคาย',
#  'สกลนคร',
#  'ยะลา',
#  'มาเลเซีย',
#  'จังหวัดร้อยเอ็ด',
#  'พระนครศรียุธยา',
#  'ูภูเก็ต',
#  'สิงห์บุรี',
#  'อุดรธานี',
#  'เชียงราย',
#  'พระนครศรีอยุธนา',
#  'ศรีษะเกษ',
#  'ศรีีสะเกษ',
#  'สรแก้ว',
#  'สมทรสาคร',
#  'เพชรบุรี',
#  'สูงเม่น',
#  'ฉะเชิงเทรา',
#  'น่าน',
#  'ตราด',
#  'จันทบุรี',
#  'นครนาชสีมา',
#  'สุรินทร์',
#  'ลพบุุรี',
#  'นนทบุรี',
#  'หนองม่วงไข่',
#  'สมุุทรสงคราม',
#  'นคนปฐม',
#  'อยุธยา',
#  'นครราชสีมา',
#  'ยานนาวา',
#  'วังชิ้น',
#  'ชััยภูมิ',
#  'ขอนแก่่น',
#  'สมุทรสงคราม',
#  'มหาสารคาม',
#  'เวียงจันทร์',
#  'ชลบุุรี',
#  'อุบลราชธานี',
#  'นครศรธรรมาช',
#  'เรือ',
#  'สุราษฎร์ธานี',
#  'สุโขทัย',
#  'พระนครศรีอยุธยา',
#  'สมุุทรปราการ',
#  'นครศรีธรรมราช',
#  'ปทุุมธานี',
#  'สมุุทรสาคร',
#  'ปลายพระยา',
#  'จ.ปัตตานี',
#  'บึงกาฬ',
#  'กระบี่',
#  'พัทลุง',
#  'บ้านหลวง',
#  'กาฬสิินธุ์',
#  'อุุดรธาน',
#  'อุุตรดิตถ์',
#  'นตรปฐม',
#  'ยโสธร',
#  'สงขลา\u200b',
#  'เลย',
#  'อุทัยธานี',
#  'สมุุทสาคร',
#  'สมุทรปาการ',
#  'บึงโขงหลง',
#  'เพชบุรี',
#  'ธารโต',
#  'ระยอง',
#  'ไม่ระบุ',
#  'อ่างทอง',
#  'ภูเก็ต',
#  'สระแก้ว',
#  'ชลบุรี',
#  'พระนครศีรอยุธยา',
#  'สมุทสาคร',
#  'กาญจนบุรี',
#  'นนทุบรี',
#  'สมุทปราการ',
#  'พม่า',
#  'ตรัง',
#  'สมุทรปราการ',
#  'ลอง',
#  'ลพบรี',
#  'ลำปาง',
#  'ชุมพร',
#  'กัมพูชา',
#  'ปทุมทานี',
#  'สุทรปราการ',
#  'ระนอง',
#  'ร้อยเอ็ด',
#  'ร้องกวาง',
#  'ขอนแก่น',
#  'บางกะปิ',
#  'เพชรบูรณ์',
#  'พระนครศีอยุธยา',
#  'นครศรีธรรรมราช',
#  'พังงา',
#  'สมุทสงคราม',
#  'นครสววรค์',
#  'อุตรดิตถ์',
#  'อุุทัยธานี',
#  'สมุทราปราการ',
#  'กาฬสินธ์ุ',
#  'กรุงเทพมหานคร',
#  'เพรชบุรี',
#  'นครพนม',
#  'ร้้อยเอ็ด',
#  'ชัยนาท',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธ์',
#  'บึึงกาฬ',
#  'นครศรีราชสีมา',
#  'นครศรี',
#  'นาวัง',
#  'แม่ฮ่องสอน',
#  'สถานที่ทำงาน',
#  'นครปฐม',
#  'นาราธิวาส',
#  'หนองบัวลำำภู',
#  'อุุดรธานี',
#  'นราธิวาส',
#  'นครราชธสีมา',
#  'นครนายก',
#  'กาฬสินธุ์',
#  'ลพบุรี',
#  'ปทุมธานีี',
#  'หนองบัวลำภู',
#  'สุมุทรสาคร',
#  'หนองบัวลำภูู',
#  'ปทุมธานี',
#  'หนองบััวลำภู',
#  'นครประฐม',
#  'ภูเพียง',
#  'ตาก',
#  'ประจวบครีขันธ์',
#  'ร้อยเอ้ด',
#  'เมือง',
#  'พระนตรศรีอยุธยา',
#  'เด่นชัย',
#  'สงขลา']

# %%
dataCN = data_cases[data_cases['province_of_onset']==X[0]] #เลือกจังหวัด ศรีสะเกษ ใน province_of_onset

# %%
dataCN
# Out:
#            No. announce_date  ... district_of_onset new col
# 290626  290627      6/7/2021  ...        กระทุ่มแบน  290626
# 290627  290628      6/7/2021  ...        กระทุ่มแบน  290627
# 456880  456881     23/7/2021  ...        กระทุ่มแบน  456880
#
# [3 rows x 12 columns]

# %%
#วนลูปตามprovince_of_onset (จังหวัดที่พบเชื้อ)เพื่ิอเติมข้อมูล mode ใน rick แล้วต่อตารางด้วย pd.concat
prov_list = list()
for e_province in list(set(data_cases['province_of_onset']))[1:]:
    print(e_province)
    dataA = data_cases[data_cases['province_of_onset']==e_province]
    dataA[['risk']] = dataA[['risk']].fillna(dataA[['risk']].dropna().mode().iloc[0,0])
    prov_list.append(dataA) ## 
dataALL = pd.concat(prov_list)
# Out:
# กาฬสินธิ์
# ปราจีนบุรี
# สุมุทรปราการ
# สองแคว
# ปัตตานี​
# เวียงสา
# กำแพงเพชร
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ร้อยเอ็็ด
# พระนครศรีอยุทธยา
# สุุราษฎร์ธานี
# เพรบุรี
# ชัยภูมิ
# ราชบุรี
# นคปฐม
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ศีรสะเกษ
# มหาสารคราม
# พิจิตร
# สงขขลา
# สระบุุรี
# นครศรีีธรรมราช
# ชุุมพร
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# อำนาจเจริญ
# ปัว
# ศรีสะเกษ
# อุบลราขธานี
# ลำพูน
# เมืองน่าน
# อุดรธานีี
# เชียงใหม่
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สระบุรี
# สอง
# สุพรรณบุรี
# บุรีรัมย์
# นครสวรรค์
# พิษณุโลก
# พะเยา
# สมุทราสาคร
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สมุทรสาคร
# สตูล
# ศีรษะเกษ
# แพร่
# มุกดาหาร
# ปัตตานี
# หนองคาย
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สกลนคร
# ยะลา
# มาเลเซีย
# จังหวัดร้อยเอ็ด
# พระนครศรียุธยา
# ูภูเก็ต
# สิงห์บุรี
# อุดรธานี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# เชียงราย
# พระนครศรีอยุธนา
# ศรีษะเกษ
# ศรีีสะเกษ
# สรแก้ว
# สมทรสาคร
# เพชรบุรี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สูงเม่น
# ฉะเชิงเทรา
# น่าน
# ตราด
# จันทบุรี
# นครนาชสีมา
# สุรินทร์
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ลพบุุรี
# นนทบุรี
# หนองม่วงไข่
# สมุุทรสงคราม
# นคนปฐม
# อยุธยา
# นครราชสีมา
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ยานนาวา
# วังชิ้น
# ชััยภูมิ
# ขอนแก่่น
# สมุทรสงคราม
# มหาสารคาม
# เวียงจันทร์
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ชลบุุรี
# อุบลราชธานี
# นครศรธรรมาช
# เรือ
# สุราษฎร์ธานี
# สุโขทัย
# พระนครศรีอยุธยา
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สมุุทรปราการ
# นครศรีธรรมราช
# ปทุุมธานี
# สมุุทรสาคร
# ปลายพระยา
# จ.ปัตตานี
# บึงกาฬ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# กระบี่
# พัทลุง
# บ้านหลวง
# กาฬสิินธุ์
# อุุดรธาน
# อุุตรดิตถ์
# นตรปฐม
# ยโสธร
# สงขลา​
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# เลย
# อุทัยธานี
# สมุุทสาคร
# สมุทรปาการ
# บึงโขงหลง
# เพชบุรี
# ธารโต
# ระยอง
# ไม่ระบุ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# อ่างทอง
# ภูเก็ต
# สระแก้ว
# ชลบุรี
# พระนครศีรอยุธยา
# สมุทสาคร
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# กาญจนบุรี
# นนทุบรี
# สมุทปราการ
# พม่า
# ตรัง
# สมุทรปราการ
# ลอง
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# ...
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# พังงา
# สมุทสงคราม
# นครสววรค์
# อุตรดิตถ์
# อุุทัยธานี
# สมุทราปราการ
# กาฬสินธ์ุ
# กรุงเทพมหานคร
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# เพรชบุรี
# นครพนม
# ร้้อยเอ็ด
# ชัยนาท
# ประจวบคีรีขันธื
# ประจวบคีรีขันธ์
# บึึงกาฬ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นครศรีราชสีมา
# นครศรี
# นาวัง
# แม่ฮ่องสอน
# สถานที่ทำงาน
# นครปฐม
# นาราธิวาส
# หนองบัวลำำภู
# อุุดรธานี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นราธิวาส
# นครราชธสีมา
# นครนายก
# กาฬสินธุ์
# ลพบุรี
# ปทุมธานีี
# หนองบัวลำภู
# สุมุทรสาคร
# หนองบัวลำภูู
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ปทุมธานี
# หนองบััวลำภู
# นครประฐม
# ภูเพียง
# ตาก
# ประจวบครีขันธ์
# ร้อยเอ้ด
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# เมือง
# พระนตรศรีอยุธยา
# เด่นชัย
# สงขลา

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 406283  406284     19/7/2021  ...           ฆ้องชัย  406283
# 406285  406286     19/7/2021  ...           ฆ้องชัย  406285
# 406300  406301     19/7/2021  ...           ฆ้องชัย  406300
# 392        393     21/3/2020  ...   เมืองปราจีนบุรี     392
# 459        460     22/3/2020  ...               NaN     459
# ...        ...           ...  ...               ...     ...
# 508633  508634     26/7/2021  ...           สิงหนคร  508633
# 508634  508635     26/7/2021  ...           สิงหนคร  508634
# 508635  508636     26/7/2021  ...           สิงหนคร  508635
# 508636  508637     26/7/2021  ...           สิงหนคร  508636
# 508637  508638     26/7/2021  ...              จะนะ  508637
#
# [512619 rows x 12 columns]

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
datamissingonset = data_cases[pd.isna(data_cases['province_of_onset'])] #ให้ datamissingonset คือ ข้อมูลที่เติมค่าว่าง(pd.isna)ลงใน 'province_of_onset'

# %%
datamissingonset
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality, province_of_isolation, risk, province_of_onset, district_of_onset, new col]
# Index: []

# %%
datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0]) #เติม mode ลงใน risk ที่ตัดค่า missigแล้ว dropna()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-107-cae8868ad368> in <module>()
# ----> 1 datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0]) #เติม mode ลงใน risk ที่ตัดค่า missigแล้ว dropna()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#     704                 raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1350             return
#    1351         elif is_integer(key):
# -> 1352             self._validate_integer(key, axis)
#    1353         elif isinstance(key, tuple):
#    1354             # a tuple should already have been caught by this point
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
dataALL = pd.concat([dataALL,datamissingonset]) #ต่อตาราง dataALLและdatamissingonset

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 406283  406284     19/7/2021  ...           ฆ้องชัย  406283
# 406285  406286     19/7/2021  ...           ฆ้องชัย  406285
# 406300  406301     19/7/2021  ...           ฆ้องชัย  406300
# 392        393     21/3/2020  ...   เมืองปราจีนบุรี     392
# 459        460     22/3/2020  ...               NaN     459
# ...        ...           ...  ...               ...     ...
# 508633  508634     26/7/2021  ...           สิงหนคร  508633
# 508634  508635     26/7/2021  ...           สิงหนคร  508634
# 508635  508636     26/7/2021  ...           สิงหนคร  508635
# 508636  508637     26/7/2021  ...           สิงหนคร  508636
# 508637  508638     26/7/2021  ...              จะนะ  508637
#
# [512619 rows x 12 columns]

# %%
data_cases #ดูข้อมูลหลังจากต่อตารางแล้ว
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL.isnull().any()  #เช็คค่า missing ถ้าเป็น False แสดงว่า ไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
dataALL = dataALL.sort_values(by='No.') #เรียงข้อมูลตาม No.
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512619 rows x 12 columns]

# %%
dataALL.keys() #ดูสมาชิก keys() ใน dataAll
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset', 'new col'],
#       dtype='object')

# %% [markdown]
# ### การทำงานกับ Datetime-Timestamp

# %%
A = data_cases.sort_values(by='announce_date') 
A
# Out:
#            No. announce_date  ... district_of_onset new col
# 7112      7113      1/1/2021  ...               NaN    7112
# 7074      7075      1/1/2021  ...               NaN    7074
# 7073      7074      1/1/2021  ...               NaN    7073
# 7072      7073      1/1/2021  ...               NaN    7072
# 7071      7072      1/1/2021  ...               NaN    7071
# ...        ...           ...  ...               ...     ...
# 317448  317449      9/7/2021  ...               NaN  317448
# 3349      3350      9/8/2020  ...               NaN    3349
# 3350      3351      9/8/2020  ...            พระนคร    3350
# 3351      3352      9/8/2020  ...           ราชเทวี    3351
# 3447      3448      9/9/2020  ...          ห้วยขวาง    3447
#
# [512622 rows x 12 columns]

# %%
from datetime import  datetime

# %%
t=pd.to_datetime(data_cases.iloc[0,1])
t
# Out:
# Timestamp('2020-12-01 00:00:00')

# %%
data_cases['announce_date']=pd.to_datetime(data_cases['announce_date'])

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1    2020-12-01  ...               NaN       0
# 1            2    2020-01-17  ...               NaN       1
# 2            3    2020-01-22  ...             เมือง       2
# 3            4    2020-01-22  ...               NaN       3
# 4            5    2020-01-24  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618    2021-07-26  ...               NaN  512617
# 512618  512619    2021-07-26  ...               NaN  512618
# 512619  512620    2021-07-26  ...               NaN  512619
# 512620  512621    2021-07-26  ...               NaN  512620
# 512621  512622    2021-07-26  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
data_cases['announce_date']=pd.to_datetime(data_cases['announce_date'],dayfirst=True)

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1    2020-12-01  ...               NaN       0
# 1            2    2020-01-17  ...               NaN       1
# 2            3    2020-01-22  ...             เมือง       2
# 3            4    2020-01-22  ...               NaN       3
# 4            5    2020-01-24  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618    2021-07-26  ...               NaN  512617
# 512618  512619    2021-07-26  ...               NaN  512618
# 512619  512620    2021-07-26  ...               NaN  512619
# 512620  512621    2021-07-26  ...               NaN  512620
# 512621  512622    2021-07-26  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL['announce_date']=pd.to_datetime(dataALL['announce_date'],dayfirst=True)

# %%
dataALL[dataALL['announce_date']==datetime(day=13,month=4,year=2020)]
# Out:
#        No. announce_date  ... district_of_onset new col
# 2552  2553    2020-04-13  ...              ถลาง    2552
# 2553  2554    2020-04-13  ...              ถลาง    2553
# 2554  2555    2020-04-13  ...             ธารโต    2554
# 2555  2556    2020-04-13  ...         ศรีสงคราม    2555
# 2556  2557    2020-04-13  ...           ยานนาวา    2556
# 2557  2558    2020-04-13  ...             วัฒนา    2557
# 2558  2559    2020-04-13  ...              ถลาง    2558
# 2559  2560    2020-04-13  ...              ถลาง    2559
# 2560  2561    2020-04-13  ...              ถลาง    2560
# 2561  2562    2020-04-13  ...              ถลาง    2561
# 2562  2563    2020-04-13  ...               NaN    2562
# 2563  2564    2020-04-13  ...            รังสิต    2563
# 2564  2565    2020-04-13  ...               NaN    2564
# 2565  2566    2020-04-13  ...               NaN    2565
# 2566  2567    2020-04-13  ...               NaN    2566
# 2567  2568    2020-04-13  ...               NaN    2567
# 2568  2569    2020-04-13  ...           มีนบุรี    2568
# 2569  2570    2020-04-13  ...               NaN    2569
# 2570  2571    2020-04-13  ...             เมือง    2570
# 2571  2572    2020-04-13  ...             เมือง    2571
# 2572  2573    2020-04-13  ...               NaN    2572
# 2573  2574    2020-04-13  ...               NaN    2573
# 2574  2575    2020-04-13  ...           บางกะปิ    2574
# 2575  2576    2020-04-13  ...          เมืองใต้    2575
# 2576  2577    2020-04-13  ...             เมือง    2576
# 2577  2578    2020-04-13  ...            ควนโดน    2577
# 2578  2579    2020-04-13  ...            ควนโดน    2578
# 2579  2580    2020-04-13  ...             สะเตง    2579
#
# [28 rows x 12 columns]

# %%
dataALL[(dataALL['announce_date']>=datetime(day=13,month=4,year=2020)) & (dataALL['announce_date']<=datetime(day=15,month=4,year=2020))]
# Out:
#        No. announce_date  ... district_of_onset new col
# 2552  2553    2020-04-13  ...              ถลาง    2552
# 2553  2554    2020-04-13  ...              ถลาง    2553
# 2554  2555    2020-04-13  ...             ธารโต    2554
# 2555  2556    2020-04-13  ...         ศรีสงคราม    2555
# 2556  2557    2020-04-13  ...           ยานนาวา    2556
# ...    ...           ...  ...               ...     ...
# 2639  2640    2020-04-15  ...           รือเสาะ    2639
# 2640  2641    2020-04-15  ...           บางกะปิ    2640
# 2641  2642    2020-04-15  ...           สวนหลวง    2641
# 2642  2643    2020-04-15  ...           คลองสาน    2642
# 2643  2644    2020-04-15  ...          ลาดพร้าว    2643
#
# [92 rows x 12 columns]

# %% [markdown]
# ### Smooth data by Binning

# %%
data_Sm=dataALL.iloc[2000:2500,4]
data_Sm
# Out:
# 2000    34.0
# 2001    31.0
# 2002    58.0
# 2003    56.0
# 2004    37.0
#         ...
# 2495    21.0
# 2496     4.0
# 2497    45.0
# 2498    30.0
# 2499    40.0
# Name: age, Length: 500, dtype: float64

# %%
plt.scatter(range(len(data_Sm)),data_Sm)

# %% [markdown]
# #### Sort

# %%
data_Sm_sorted=data_Sm.sort_values()

# %%
data_Sm_sorted
# Out:
# 2455     1.0
# 2259     1.0
# 2180     2.0
# 2448     2.0
# 2376     3.0
#         ...
# 2494    75.0
# 2337    77.0
# 2219    78.0
# 2183    81.0
# 2483    91.0
# Name: age, Length: 500, dtype: float64

# %% [markdown]
# #### Bin

# %%
import numpy as np

bin = 10 #กำหนดให้เป็น 10
bin_r = []
for i in range(bin):
    step = int(len(data_Sm_sorted)/bin)
    this_data = data_Sm_sorted[(step*i) : (step*i)+step]
    rep = np.mean(this_data)

    bin_r.append(rep)

# %%
bin_r
# Out:
# [14.74,
#  24.0,
#  28.24,
#  32.28,
#  35.82235762327721,
#  39.14,
#  43.84,
#  49.74,
#  56.56,
#  67.0]

# %% [markdown]
# ####Smooth

# %%
this_bin =0
data_Sm_Smooth = list()
step =0
for i in data_Sm_sorted:
    if step < 50 :
        data_Sm_Smooth.append({'old_v':i,'new_v' : bin_r[this_bin]}) 
        step= step +1
    else:
        step = 0
        this_bin = this_bin + 1
        data_Sm_Smooth.append({'old_v':i,'new_v' : bin_r[this_bin]})

# %%
my_df = pd.DataFrame[data_Sm_Smooth ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-806c77bb6cd3> in <module>()
# ----> 1 my_df = pd.DataFrame[data_Sm_Smooth ]
#
# TypeError: 'type' object is not subscriptable
